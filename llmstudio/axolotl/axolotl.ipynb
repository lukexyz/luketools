# %% [markdown]
# # What is `Axolotl`?
# * Wrapper for huggingface tools
# * Easy to use. So you can focus on your data.
# * Best practices built in
#
# → https://github.com/OpenAccess-AI-Collective/axolotl?tab=readme-ov-file#quickstart
#
# ### How to get started?
# * Go to the readme of the repo and look at the [examples](https://github.com/OpenAccess-AI-Collective/axolotl/tree/main/examples) docs.
# * Copy the config file that is right for you.
#     * → i.e. [axolotl/examples/phi
# /phi2-ft.yml](https://github.com/OpenAccess-AI-Collective/axolotl/blob/main/examples/phi/phi2-ft.yml)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as np

# %% [markdown]
# Example dataset:
#     → https://huggingface.co/datasets/mhenrichsen/alpaca_2k_test
#
# ![image.png](attachment:image.png)
